# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import os

data_dir = r"C:\Users\47613\Desktop\UNSW25 T1\9517\project\mygo-9517-main\mygo-9517-main\archive\balanced"

basic_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

train_transform = basic_transform
val_test_transform = basic_transform

train_dataset = datasets.ImageFolder(root=os.path.join(data_dir, "train"), transform=train_transform)
val_dataset   = datasets.ImageFolder(root=os.path.join(data_dir, "val"), transform=val_test_transform)
test_dataset  = datasets.ImageFolder(root=os.path.join(data_dir, "test"), transform=val_test_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

class_names = train_dataset.classes

# %%
import torch
import torch.nn as nn
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
import torch.optim as optim
from sklearn.metrics import classification_report

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# EfficientNet-B0
weights = EfficientNet_B0_Weights.DEFAULT
model = efficientnet_b0(weights=weights)

num_classes = 15
model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)

model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
train_loss_list = []
val_loss_list = []
train_acc_list = []
val_acc_list = []

def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=10):
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")
        # Train
        model.train()
        train_loss = 0
        train_correct = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            train_correct += torch.sum(preds == labels.data)

        epoch_train_loss = train_loss / len(train_loader.dataset)
        epoch_train_acc = train_correct.double() / len(train_loader.dataset)

        # Validation
        model.eval()
        val_loss = 0
        val_correct = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels.data)

        epoch_val_loss = val_loss / len(val_loader.dataset)
        epoch_val_acc = val_correct.double() / len(val_loader.dataset)

        train_loss_list.append(epoch_train_loss)
        val_loss_list.append(epoch_val_loss)
        train_acc_list.append(epoch_train_acc.item())
        val_acc_list.append(epoch_val_acc.item())

        print(f"Train Loss: {epoch_train_loss:.4f}, Train Acc: {epoch_train_acc:.4f}")
        print(f"Val   Loss: {epoch_val_loss:.4f}, Val   Acc: {epoch_val_acc:.4f}")
    return model, train_loss_list, val_loss_list, train_acc_list, val_acc_list

# %%
model, train_loss_list, val_loss_list, train_acc_list, val_acc_list = train_model(
    model, criterion, optimizer, train_loader, val_loader, num_epochs=20
)
# Out:
# Epoch 1/20
# Train Loss: 1.0376, Train Acc: 0.7628
# Val   Loss: 0.1967, Val   Acc: 0.9521
# Epoch 2/20
# Train Loss: 0.2077, Train Acc: 0.9415
# Val   Loss: 0.1043, Val   Acc: 0.9700
# Epoch 3/20
# Train Loss: 0.1125, Train Acc: 0.9718
# Val   Loss: 0.0963, Val   Acc: 0.9713
# Epoch 4/20
# Train Loss: 0.0765, Train Acc: 0.9797
# Val   Loss: 0.0846, Val   Acc: 0.9721
# Epoch 5/20
# Train Loss: 0.0473, Train Acc: 0.9860
# Val   Loss: 0.0802, Val   Acc: 0.9746
# Epoch 6/20
# Train Loss: 0.0406, Train Acc: 0.9882
# Val   Loss: 0.0769, Val   Acc: 0.9746
# Epoch 7/20
# Train Loss: 0.0343, Train Acc: 0.9915
# Val   Loss: 0.0697, Val   Acc: 0.9779
# Epoch 8/20
# Train Loss: 0.0315, Train Acc: 0.9911
# Val   Loss: 0.0706, Val   Acc: 0.9788
# Epoch 9/20
# Train Loss: 0.0253, Train Acc: 0.9939
# Val   Loss: 0.0795, Val   Acc: 0.9763
# Epoch 10/20
# Train Loss: 0.0199, Train Acc: 0.9949
# Val   Loss: 0.0734, Val   Acc: 0.9783
# Epoch 11/20
# Train Loss: 0.0231, Train Acc: 0.9933
# Val   Loss: 0.0741, Val   Acc: 0.9788
# Epoch 12/20
# Train Loss: 0.0201, Train Acc: 0.9935
# Val   Loss: 0.0810, Val   Acc: 0.9775
# Epoch 13/20
# Train Loss: 0.0171, Train Acc: 0.9947
# Val   Loss: 0.0801, Val   Acc: 0.9792
# Epoch 14/20
# Train Loss: 0.0121, Train Acc: 0.9965
# Val   Loss: 0.0863, Val   Acc: 0.9763
# Epoch 15/20
# Train Loss: 0.0143, Train Acc: 0.9961
# Val   Loss: 0.0755, Val   Acc: 0.9779
# Epoch 16/20
# Train Loss: 0.0123, Train Acc: 0.9969
# Val   Loss: 0.0818, Val   Acc: 0.9792
# Epoch 17/20
# Train Loss: 0.0122, Train Acc: 0.9961
# Val   Loss: 0.0805, Val   Acc: 0.9796
# Epoch 18/20
# Train Loss: 0.0092, Train Acc: 0.9978
# Val   Loss: 0.0853, Val   Acc: 0.9792
# Epoch 19/20
# Train Loss: 0.0181, Train Acc: 0.9936
# Val   Loss: 0.0960, Val   Acc: 0.9763
# Epoch 20/20
# Train Loss: 0.0126, Train Acc: 0.9968
# Val   Loss: 0.0816, Val   Acc: 0.9783

# %%
def evaluate_model(model, test_loader, class_names):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    print("Classification Report:\n")
    print(classification_report(all_labels, all_preds, target_names=class_names))

# %%
evaluate_model(model, test_loader, class_names)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  Agriculture       0.99      0.97      0.98       160
#      Airport       0.98      0.97      0.98       160
#        Beach       0.99      0.97      0.98       160
#         City       0.97      0.98      0.98       160
#       Desert       0.93      0.98      0.95       160
#       Forest       0.98      1.00      0.99       160
#    Grassland       0.99      0.99      0.99       160
#      Highway       0.99      0.98      0.99       160
#         Lake       0.98      0.99      0.98       160
#     Mountain       0.97      0.97      0.97       160
#      Parking       0.99      0.99      0.99       160
#         Port       1.00      1.00      1.00       160
#      Railway       0.97      0.98      0.98       160
#  Residential       0.99      0.98      0.98       160
#        River       1.00      0.94      0.97       160
#
#     accuracy                           0.98      2400
#    macro avg       0.98      0.98      0.98      2400
# weighted avg       0.98      0.98      0.98      2400

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

y_true = []
y_pred = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

labels = list(report.keys())[:-3]
precision = [report[label]["precision"] for label in labels]
recall    = [report[label]["recall"] for label in labels]
f1        = [report[label]["f1-score"] for label in labels]

x = np.arange(len(labels))
width = 0.25

plt.figure(figsize=(14, 6))
plt.bar(x - width, precision, width=width, label='Precision')
plt.bar(x,         recall,    width=width, label='Recall')
plt.bar(x + width, f1,        width=width, label='F1-score')

plt.xticks(x, labels, rotation=45)
plt.ylim(0.90, 1.01)
plt.ylabel("Score")
plt.title("Precision / Recall / F1-score by Class")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, len(train_loss_list) + 1))

plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss_list, marker='o', label='EfficientNet Train Loss')
plt.plot(epochs, val_loss_list, marker='s', label='EfficientNet Val Loss')
plt.title("EfficientNet - Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc_list, marker='o', label='EfficientNet Train Accuracy')
plt.plot(epochs, val_acc_list, marker='s', label='EfficientNet Val Accuracy')
plt.title("EfficientNet - Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f"Manual Accuracy : {acc:.4f}")
print(f"Sklearn Accuracy: {acc:.4f}")
print(f"Precision       : {precision:.4f}")
print(f"Recall          : {recall:.4f}")
print(f"F1-Score        : {f1:.4f}")
# Out:
# Manual Accuracy : 0.9812
# Sklearn Accuracy: 0.9812
# Precision       : 0.9816
# Recall          : 0.9812
# F1-Score        : 0.9813

# %%
# ResNet
import torchvision.models as models
resnet_model = models.resnet18(pretrained=True)
resnet_model.fc = nn.Linear(resnet_model.fc.in_features, len(class_names))
resnet_model = resnet_model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet_model.parameters(), lr=0.001)

# train_model
resnet_model, resnet_train_loss, resnet_val_loss, resnet_train_acc, resnet_val_acc = train_model(
    resnet_model, criterion, optimizer, train_loader, val_loader, num_epochs=20
)
# Out:
# C:\Users\47613\anaconda3\envs\9517\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\47613\anaconda3\envs\9517\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/20
# Train Loss: 0.8383, Train Acc: 0.7500
# Val   Loss: 0.4439, Val   Acc: 0.8563
# Epoch 2/20
# Train Loss: 0.4607, Train Acc: 0.8514
# Val   Loss: 0.5812, Val   Acc: 0.8267
# Epoch 3/20
# Train Loss: 0.3407, Train Acc: 0.8912
# Val   Loss: 0.4631, Val   Acc: 0.8467
# Epoch 4/20
# Train Loss: 0.2732, Train Acc: 0.9114
# Val   Loss: 0.2975, Val   Acc: 0.9046
# Epoch 5/20
# Train Loss: 0.2060, Train Acc: 0.9344
# Val   Loss: 0.3207, Val   Acc: 0.9054
# Epoch 6/20
# Train Loss: 0.1642, Train Acc: 0.9467
# Val   Loss: 0.3241, Val   Acc: 0.9092
# Epoch 7/20
# Train Loss: 0.1696, Train Acc: 0.9471
# Val   Loss: 0.2745, Val   Acc: 0.9221
# Epoch 8/20
# Train Loss: 0.1452, Train Acc: 0.9518
# Val   Loss: 0.5420, Val   Acc: 0.8517
# Epoch 9/20
# Train Loss: 0.1615, Train Acc: 0.9513
# Val   Loss: 0.3212, Val   Acc: 0.9067
# Epoch 10/20
# Train Loss: 0.0925, Train Acc: 0.9674
# Val   Loss: 0.2334, Val   Acc: 0.9363
# Epoch 11/20
# Train Loss: 0.0831, Train Acc: 0.9739
# Val   Loss: 0.3819, Val   Acc: 0.9025
# Epoch 12/20
# Train Loss: 0.0891, Train Acc: 0.9712
# Val   Loss: 0.2718, Val   Acc: 0.9279
# Epoch 13/20
# Train Loss: 0.1222, Train Acc: 0.9613
# Val   Loss: 0.3586, Val   Acc: 0.9067
# Epoch 14/20
# Train Loss: 0.0996, Train Acc: 0.9694
# Val   Loss: 0.2895, Val   Acc: 0.9283
# Epoch 15/20
# Train Loss: 0.0610, Train Acc: 0.9822
# Val   Loss: 0.6789, Val   Acc: 0.8483
# Epoch 16/20
# Train Loss: 0.0679, Train Acc: 0.9772
# Val   Loss: 0.2453, Val   Acc: 0.9367
# Epoch 17/20
# Train Loss: 0.0510, Train Acc: 0.9842
# Val   Loss: 0.4300, Val   Acc: 0.8913
# Epoch 18/20
# Train Loss: 0.0919, Train Acc: 0.9681
# Val   Loss: 0.3381, Val   Acc: 0.9192
# Epoch 19/20
# Train Loss: 0.0938, Train Acc: 0.9683
# Val   Loss: 0.3784, Val   Acc: 0.9096
# Epoch 20/20
# Train Loss: 0.0649, Train Acc: 0.9801
# Val   Loss: 0.3865, Val   Acc: 0.9083

# %%
def evaluate_model(model, test_loader, class_names):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    print("Classification Report:\n")
    print(classification_report(all_labels, all_preds, target_names=class_names))

# %%
evaluate_model(resnet_model, test_loader, class_names)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  Agriculture       0.88      0.97      0.92       160
#      Airport       0.85      0.83      0.84       160
#        Beach       0.91      0.96      0.94       160
#         City       0.92      0.94      0.93       160
#       Desert       0.87      0.96      0.91       160
#       Forest       0.86      0.99      0.92       160
#    Grassland       0.83      0.96      0.89       160
#      Highway       0.92      0.93      0.92       160
#         Lake       0.90      0.92      0.91       160
#     Mountain       0.82      0.84      0.83       160
#      Parking       0.95      0.97      0.96       160
#         Port       0.99      0.86      0.92       160
#      Railway       0.93      0.80      0.86       160
#  Residential       0.98      0.93      0.95       160
#        River       0.97      0.66      0.79       160
#
#     accuracy                           0.90      2400
#    macro avg       0.91      0.90      0.90      2400
# weighted avg       0.91      0.90      0.90      2400

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

y_true = []
y_pred = []

resnet_model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = resnet_model(images)
        _, preds = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("ResNet Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

labels = list(report.keys())[:-3]
precision = [report[label]["precision"] for label in labels]
recall    = [report[label]["recall"]    for label in labels]
f1        = [report[label]["f1-score"]  for label in labels]

x = np.arange(len(labels))
width = 0.25

plt.figure(figsize=(14, 6))
plt.bar(x - width, precision, width=width, label='Precision')
plt.bar(x,         recall,    width=width, label='Recall')
plt.bar(x + width, f1,        width=width, label='F1-score')

plt.xticks(x, labels, rotation=45)
plt.ylim(0.90, 1.01)
plt.ylabel("Score")
plt.title("ResNet: Precision / Recall / F1-score by Class")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, len(resnet_train_loss) + 1))

plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, resnet_train_loss, marker='o', label='Train Loss')
plt.plot(epochs, resnet_val_loss, marker='s', label='Validation Loss')
plt.title('ResNet - Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, resnet_train_acc, marker='o', label='Train Accuracy')
plt.plot(epochs, resnet_val_acc, marker='s', label='Validation Accuracy')
plt.title('ResNet - Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print(f"Manual Accuracy : {acc:.4f}")
print(f"Sklearn Accuracy: {acc:.4f}")
print(f"Precision       : {precision:.4f}")
print(f"Recall          : {recall:.4f}")
print(f"F1-Score        : {f1:.4f}")
# Out:
# Manual Accuracy : 0.9021
# Sklearn Accuracy: 0.9021
# Precision       : 0.9063
# Recall          : 0.9021
# F1-Score        : 0.9006
